# %%
# !python models/model_utils.py
# Out:
# tensor(1.6880e-08, grad_fn=<MeanBackward0>)
# tensor([1.0000, 1.0000, 1.0000], grad_fn=<StdBackward0>) tensor([ 1.2895e-09, -6.3043e-09,  1.5761e-09], grad_fn=<MeanBackward1>)

# %%
# !python -m models.conv_iResNet  # needs pip install linear_operator
# Out:
# tensor([-1.3863, -1.3863]) tensor([-1.3863, -1.3863])
# block
# 0 tensor(3226.3250, grad_fn=<SumBackward0>)
# 1 tensor(158.5352, grad_fn=<SumBackward0>)
# 2 tensor(104.7997, grad_fn=<SumBackward0>)
# 3 tensor(123.6484, grad_fn=<SumBackward0>)
# 4 tensor(133.0422, grad_fn=<SumBackward0>)
# 5 tensor(137.0303, grad_fn=<SumBackward0>)
# 6 tensor(138.8905, grad_fn=<SumBackward0>)
# 7 tensor(139.8434, grad_fn=<SumBackward0>)
# 8 tensor(140.3247, grad_fn=<SumBackward0>)
# 9 tensor(140.5506, grad_fn=<SumBackward0>)
# scale block
# 0 tensor(5426.7570, grad_fn=<SumBackward0>)
# 1 tensor(608.9427, grad_fn=<SumBackward0>)
# 2 tensor(897.1801, grad_fn=<SumBackward0>)
# 3 tensor(1080.1020, grad_fn=<SumBackward0>)
# 4 tensor(1169.0881, grad_fn=<SumBackward0>)
#
#  == Building iResNet 37 ==
# ResNet Shape: (192, 4, 4)
# 0 iters error 6361.290649228325
# 1 iters error 406.66991563537306
# 2 iters error 498.30343529634854
# 3 iters error 568.2324331681402
# 4 iters error 602.2462915857375
# ...

# %%
# !python chebyshev_utils.py
# Out:
# Relative error (function action): 0.15404532992470318
# Relative error (bilinear form): 0.1540453299247032
# Norm of A: 16.496293931364455
# Trace of A: -0.18391504724290947
#
# --- logdet via Chebyshev ---
# Chebyshev coeffs log(1 + x)      : [-0.69245403  1.99861371 -0.9986137   0.66528037 -0.4986137   0.39861369
#  -0.33194702]
# Exact Chebyshev coeffs log(1 + x): [-0.69314718  2.         -1.          0.66666667 -0.5         0.4
#  -0.33333333]
# Estimated trace of log(I + A):    -189.2455234201113
# True logdet(I + A):               SlogdetResult(sign=np.float64(1.0), logabsdet=np.float64(-198.68258133055633))

# %%
# !python matrix_utils.py
